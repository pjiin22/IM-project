# %%
import pandas as pd
from konlpy.tag import Okt
from collections import Counter


import warnings
warnings.filterwarnings('ignore')

# %%
A = pd.read_csv('Desktop/병합데이터.csv')

# %%
df = A[['서비스명', '대분류', '서비스번호', '판매자']]

# %%
df
# Out:
#                                    서비스명  대분류   서비스번호    판매자
# 0         카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수  커머스  2102.0  logf1
# 1         카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수  커머스  2102.0  logf1
# 2       엑셀 VBA, 매크로, ERP 프로그램 개발해 드립니다.  데이터  2103.0   엑셀의신
# 3         엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍  데이터  2105.0    태구리
# 4         엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍  데이터  2105.0    태구리
# ...                                 ...  ...     ...    ...
# 344272           데이터 분석 및 시각화 제공해 드립니다.  데이터  2600.0  전문가오리
# 344273           데이터 분석 및 시각화 제공해 드립니다.  데이터  2600.0  전문가오리
# 344274           데이터 분석 및 시각화 제공해 드립니다.  데이터  2600.0  전문가오리
# 344275           데이터 분석 및 시각화 제공해 드립니다.  데이터  2600.0  전문가오리
# 344276           데이터 분석 및 시각화 제공해 드립니다.  데이터  2600.0  전문가오리
#
# [344277 rows x 4 columns]

# %% [markdown]
# **대분류명 확인**

# %%
df['대분류'].unique()
# Out:
# array(['커머스', '데이터', '홈페이지', '기타', '프로그램', '프로그래밍', '모바일', '디자인', '게임',
#        '기획', 'UnReal', '인공지능'], dtype=object)

# %% [markdown]
# **서비스명 확인**

# %%
uni = df['서비스명'].unique()

for i in uni[:5]:  
    print(i)
# Out:
# 카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수
# 엑셀 VBA, 매크로, ERP 프로그램 개발해 드립니다.
# 엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍
# 카페24 쇼핑몰 수정 유지보수 제작 기능개선 오류개선
# 카페24 쇼핑몰 수정 및 개선작업 해 드립니다.

# %% [markdown]
# ### 1차 카테고리 생성

# %%
okt = Okt()

categories = {
    '웹빌더': ['워드프레스', '카페24', '아임웹', '노션'],
    '웹 제작': ['홈페이지', '쇼핑몰', '랜딩페이지'],
    '웹 유지보수': ['수정', '유지보수', '퍼블리싱', '검색최적화', 'SEO', '애널리틱스'],
    '프로그램 자동화': ['자동화'],
    '크롤링.스크래핑': ['크롤링', '스크래핑'],
    '프로그램 유지보수': ['유지보수', '프로그램 수정'],
    '서버.클라우드': ['서버', '클라우드'],
    '액셀.스프레드시트': ['엑셀', '스프레드시트'],
    '봇.챗봇': ['봇', '챗봇'],
    'AI.GPT': ['AI', 'GPT'],
    '머신러닝 딥러닝': ['머신러닝', '딥러닝'],
    '컴퓨터 비전.자연어 처리': ['컴퓨터 비전', '자연어'],
    '데이터 라벨링': ['라벨링'],
    '데이터 전처리.분석.시각화': ['전처리', '분석', '시각화'],
    '데이터베이스': ['데이터베이스'],
    '데이터 구매': ['데이터 구매', '구축'],
    '정보.보안': ['보안', '정보 보안'],
    'QA.테스트': ['QA', '테스트'],
    '게임·AR·VR': ['게임', 'AR', 'VR'],
    '메타버스': ['메타버스'],
    '블록체인·NFT': ['블록체인', 'NFT'],
    '직무직군': ['UI', 'UX', '기획', '프론트엔드', '백엔드', '풀스택', '데브옵스', '인프라', 'ML', 'DL'],
    '서비스·MVP 개발': ['서비스 개발', 'MVP'],
    '컴퓨터 기술지원': ['기술지원'],
    '하드웨어·임베디드': ['하드웨어', '임베디드'],
    '기타': ['기타']
}

# %%
df_unique = df.drop_duplicates(subset='서비스명').copy()

for idx, row in df_unique.iterrows():
    service_name = row['서비스명']
    nouns = okt.nouns(service_name)  
    matched_categories = set()  

    for noun in nouns:
        for category, keywords in categories.items():
            if noun in keywords:
                matched_categories.add(category)

    df_unique.at[idx, '소분류'] = ', '.join(matched_categories) if matched_categories else '기타'

# %%
df_unique[['서비스명', '소분류']].head(10)
# Out:
#                                    서비스명                        소분류
# 0         카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수               웹 제작, 웹 유지보수
# 2       엑셀 VBA, 매크로, ERP 프로그램 개발해 드립니다.                  액셀.스프레드시트
# 3         엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍  데이터 전처리.분석.시각화, 액셀.스프레드시트
# 11        카페24 쇼핑몰 수정 유지보수 제작 기능개선 오류개선               웹 제작, 웹 유지보수
# 18           카페24 쇼핑몰 수정 및 개선작업 해 드립니다.               웹 제작, 웹 유지보수
# 20            리눅스 서버 기술지원 서버이전 SSL 장애처리                    서버.클라우드
# 21          워드프레스 홈페이지 수정, 오류 해결, 기능 추가          웹 제작, 웹빌더, 웹 유지보수
# 23       쎈스있는 카페24 수정유지보수 리뉴얼 코딩 해드립니다.                     웹 유지보수
# 25  고도몰5 전문 튜닝 친절한 상담과 깔끔한 작업 진행해 드립니다.                         기타
# 28           알고리즘 자료구조 등 프로그램 제작해 드립니다.                         기타

# %%
rr = (df_unique['소분류'] == '기타').mean() * 100
rr
# Out:
# 46.68101901686401

# %% [markdown]
# ### 카테고리 개선 : 기타 줄이기

# %%
ext = df_unique[df_unique['소분류'] == '기타']

ext
# Out:
#                                              서비스명    대분류   서비스번호     판매자 소분류
# 25            고도몰5 전문 튜닝 친절한 상담과 깔끔한 작업 진행해 드립니다.     기타  2115.0  웹개발윤서준  기타
# 28                     알고리즘 자료구조 등 프로그램 제작해 드립니다.   프로그램  2116.0  개발자김명준  기타
# 79              크롤링 , 크롤러 , 파싱 , 파싱기 맞춤 제작해 드립니다.    데이터  2123.0     비트박  기타
# 86      PHP, 그누보드, 영카트, 고도몰, 카페24 등 개발, 코딩해 드립니다.  프로그래밍  2124.0     디바인  기타
# 130                         간단한 아두이노 장치 제작해 드립니다.  프로그래밍  2130.0    수제비1  기타
# ...                                           ...    ...     ...     ...  ..
# 339089                개발의 기초가 되는 웹, 어플리케이션 기획서 제작   홈페이지  6469.0  다재다능중수  기타
# 340223               TOP BDS 아파트부동산 거래가/거래량 드립니다.     기타  6473.0  유민에브리띵  기타
# 342863          보기만 해도 눈이 즐거운 애드센스 블로그를 만들어 드립니다.     기타  6484.0      웹핏  기타
# 343783                     기술중심의 백서 및 황서 제작해드립니다.  프로그래밍  6488.0   아틀란기획  기타
# 344213             대화형 이러닝 동영상 강의 플레이어를 설치해 드립니다.     기타  6494.0    공부나라  기타
#
# [1301 rows x 5 columns]

# %%
box = []

for k in ext['서비스명']:
    nouns = okt.nouns(k)  
    box.append(nouns)

# %% [markdown]
# **카테고리 수정**

# %%
categories = {
    '웹빌더': ['워드프레스', '카페24', '아임웹', '노션'],
    '웹 제작': ['홈페이지', '쇼핑몰', '랜딩페이지','튜닝'],
    '웹 유지보수': ['수정', '유지보수', '퍼블리싱', '검색최적화', 'SEO', '애널리틱스','유지'],
    '프로그램 자동화': ['자동화','알고리즘','자료구조','반복'],
    '크롤링.스크래핑': ['크롤링', '스크래핑','크롤','데이터'],
    '코딩' : ['코딩'],
    '프로그램 유지보수': ['유지보수', '프로그램 수정'],
    '서버.클라우드': ['서버', '클라우드'],
    '액셀.스프레드시트': ['엑셀', '스프레드시트','구글'],
    '봇.챗봇': ['봇', '챗봇'],
    'AI.GPT': ['AI', 'GPT','오픈소스'],
    '머신러닝 딥러닝': ['머신러닝', '딥러닝'],
    '컴퓨터 비전.자연어 처리': ['컴퓨터 비전', '자연어'],
    '데이터 라벨링': ['라벨링'],
    '데이터 전처리.분석.시각화': ['전처리', '분석', '시각화'],
    '데이터베이스': ['데이터베이스','쿼리'],
    '데이터 구매': ['데이터 구매', '구축'],
    '정보.보안': ['보안', '정보 보안'],
    'QA.테스트': ['QA', '테스트'],
    '게임·AR·VR': ['게임', 'AR', 'VR'],
    '메타버스': ['메타버스'],
    '블록체인·NFT': ['블록체인', 'NFT'],
    '직무직군': ['UI', 'UX', '기획', '프론트엔드', '백엔드', '풀스택', '데브옵스', '인프라', 'ML', 'DL'],
    '서비스·MVP 개발': ['서비스 개발', 'MVP'],
    '컴퓨터 기술지원': ['기술지원'],
    '하드웨어·임베디드': ['하드웨어', '임베디드','컴퓨터','설치','아두이노'],
    '기타': ['기타','장치']
}

# %%
df_unique = df.drop_duplicates(subset='서비스명').copy()

for idx, row in df_unique.iterrows():
    service_name = row['서비스명']
    nouns = okt.nouns(service_name)  
    matched_categories = set()  

    for noun in nouns:
        for category, keywords in categories.items():
            if noun in keywords:
                matched_categories.add(category)

    df_unique.at[idx, '소분류'] = ', '.join(matched_categories) if matched_categories else '기타'

# %%
df_unique[['서비스명', '소분류']].head(10)
# Out:
#                                    서비스명                        소분류
# 0         카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수           웹 제작, 코딩, 웹 유지보수
# 2       엑셀 VBA, 매크로, ERP 프로그램 개발해 드립니다.                  액셀.스프레드시트
# 3         엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍  데이터 전처리.분석.시각화, 액셀.스프레드시트
# 11        카페24 쇼핑몰 수정 유지보수 제작 기능개선 오류개선               웹 제작, 웹 유지보수
# 18           카페24 쇼핑몰 수정 및 개선작업 해 드립니다.               웹 제작, 웹 유지보수
# 20            리눅스 서버 기술지원 서버이전 SSL 장애처리                    서버.클라우드
# 21          워드프레스 홈페이지 수정, 오류 해결, 기능 추가          웹 제작, 웹빌더, 웹 유지보수
# 23       쎈스있는 카페24 수정유지보수 리뉴얼 코딩 해드립니다.                 웹 유지보수, 코딩
# 25  고도몰5 전문 튜닝 친절한 상담과 깔끔한 작업 진행해 드립니다.                       웹 제작
# 28           알고리즘 자료구조 등 프로그램 제작해 드립니다.                   프로그램 자동화

# %%
ratio = (df_unique['소분류'] == '기타').mean() * 100
ratio
# Out:
# 35.12737710800143

# %% [markdown]
# ### 카테고리 개선2
# - 기타 줄이기
# - 가장 많이 겹치는 소분류로 정의하기

# %%
E = df_unique[df_unique['소분류'] == '기타']


L = []

for h in E['서비스명']:
    nouns = okt.nouns(h)  
    L.append(nouns)

L[50:60]
# Out:
# [['머신', '러닝', '딥', '러닝', '업', '최', '전방', '엔지니어'],
#  ['그누보드', '카트', '기능', '추가', '및', '개선'],
#  ['관리', '시스템', '제작'],
#  ['웹', '프로젝트', '동해'],
#  ['유니티', '를', '사용', '콘텐츠', '구현'],
#  ['일러스트레이터', '스트립', '트', '제작'],
#  ['웹', '웹', '애플리케이션', '제작'],
#  ['출신', '기술', '지원'],
#  ['웹', '페이지', '렌딩', '페이지', '제작'],
#  ['안드로이드', '어플리케이션', '제작']]

# %%
categories = {
    '웹빌더': ['워드프레스', '카페24', '아임웹', '노션','웹'],
    '웹 제작': ['홈페이지', '쇼핑몰', '랜딩페이지','튜닝','웹','랜딩'],
    '웹 유지보수': ['수정', '유지보수', '퍼블리싱', '검색최적화', 'SEO', '애널리틱스','유지','개발','웹'],
    '프로그램 자동화': ['자동화','알고리즘','자료구조','반복','트레이딩뷰'],
    '크롤링.스크래핑': ['크롤링', '스크래핑','크롤','데이터'],
    '코딩' : ['코딩'],
    '프로그램 유지보수': ['유지보수', '프로그램 수정','프로그램','재작'],
    '앱' : ['앱','안드로이드'],
    '서버.클라우드': ['서버', '클라우드','아마존'],
    '액셀.스프레드시트': ['엑셀', '스프레드시트','구글'],
    '봇.챗봇': ['봇', '챗봇'],
    'AI.GPT': ['AI', 'GPT','오픈소스'],
    '머신러닝 딥러닝': ['머신러닝', '딥러닝'],
    '컴퓨터 비전.자연어 처리': ['컴퓨터 비전', '자연어'],
    '데이터 라벨링': ['라벨링'],
    '데이터 전처리.분석.시각화': ['전처리', '분석', '시각화'],
    '데이터베이스': ['데이터베이스','쿼리'],
    '데이터 구매': ['데이터 구매', '구축','수집'],
    '정보.보안': ['보안', '정보 보안'],
    'QA.테스트': ['QA', '테스트'],
    '게임·AR·VR': ['게임', 'AR', 'VR','유니티'],
    '메타버스': ['메타버스'],
    '블록체인·NFT': ['블록체인', 'NFT'],
    '직무직군': ['UI', 'UX', '기획', '프론트엔드', '백엔드', '풀스택', '데브옵스', '인프라', 'ML', 'DL'],
    '서비스·MVP 개발': ['서비스 개발', 'MVP'],
    '컴퓨터 기술지원': ['기술지원'],
    '하드웨어·임베디드': ['하드웨어', '임베디드','컴퓨터','설치','아두이노'],
    '기타': ['기타','장치']
}

# %%
for idx, row in df_unique.iterrows():
    service_name = row['서비스명']
    nouns = okt.nouns(service_name)  
    category_count = Counter()  

    for noun in nouns:
        for category, keywords in categories.items():
            if noun in keywords:
                category_count[category] += 1

    if category_count:
        most_common_category = category_count.most_common(1)[0][0]  
        df_unique.at[idx, '소분류'] = most_common_category
    else:
        df_unique.at[idx, '소분류'] = '기타'

# %%
df_unique[['서비스명', '소분류']].head(10)
# Out:
#                                    서비스명        소분류
# 0         카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수     웹 유지보수
# 2       엑셀 VBA, 매크로, ERP 프로그램 개발해 드립니다.  액셀.스프레드시트
# 3         엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍  액셀.스프레드시트
# 11        카페24 쇼핑몰 수정 유지보수 제작 기능개선 오류개선     웹 유지보수
# 18           카페24 쇼핑몰 수정 및 개선작업 해 드립니다.       웹 제작
# 20            리눅스 서버 기술지원 서버이전 SSL 장애처리    서버.클라우드
# 21          워드프레스 홈페이지 수정, 오류 해결, 기능 추가        웹빌더
# 23       쎈스있는 카페24 수정유지보수 리뉴얼 코딩 해드립니다.     웹 유지보수
# 25  고도몰5 전문 튜닝 친절한 상담과 깔끔한 작업 진행해 드립니다.       웹 제작
# 28           알고리즘 자료구조 등 프로그램 제작해 드립니다.   프로그램 자동화

# %%
(df_unique['소분류'] == '기타').mean() * 100
# Out:
# 15.464657337639037

# %% [markdown]
# ### 카테고리 개선3

# %%
el = df_unique[df_unique['소분류'] == '기타']


li = []

for i in el['서비스명']:
    nouns = okt.nouns(i)  
    li.append(nouns)

li
# Out:
# [['이미지', '디자인', '파일', '벡터', '제작'],
#  ['기술', '지원', '해'],
#  ['웹페이지'],
#  ['이용', '매크로', '레포트', '등'],
#  ['반응', '최적화', '이북', '제작', '웹북', '제작', '이북', '샘플', '확인'],
#  ['온라인', '격', '포맷', '해'],
#  ['카페', '스마트', '스토어', '메이크', '배너', '및', '세팅'],
#  [],
#  ['파이썬', '프로그래밍'],
#  ['아두이노', '라즈베리파이', '기타', '기능', '장치', '개발'],
#  ['프로그래밍', '도'],
#  ['퀄리티', '매크로', '제작'],
#  ['기술'],
#  ['편집', '해'],
#  ['가상', '화폐', '코인', '보조', '지표', '맞춤', '제작'],
#  ['도메인', '연결', '도메인', '주소', '기업', '이메일', '세팅해'],
#  ['때'],
#  ['기능', '추가', '변경', '해'],
#  ['사용', '머신', '러닝', '신경망', '모델'],
#  ['도'],
#  ['머신', '러닝', '딥', '러닝', '모델'],
#  ['그누보드', '기능', '스텀', '해'],
#  ['자신', '로또', '툴'],
#  ['기존', '웹사이트', '개선'],
#  ['용도', '견적'],
#  ['운영', '웹사이트', '개선', '및', '오류', '정해'],
#  ['프로그래밍'],
#  ['바이', '낸스', '제작'],
#  ['머신', '러닝', '딥', '러닝', '모든', '주제', '프로젝트', '진행'],
#  ['코인', '자동', '매매', '솔루션', '전략', '구현'],
#  ['회로', '설계', '및', '설계', '및', '제작', '해'],
#  ['고객', '맞춤', '전자회로', '제품', '제작'],
#  ['고도', '퍼스트', '그누보드', '작업'],
# ...

# %%
categories = {
    '웹빌더': ['워드프레스', '카페24', '아임웹', '노션', '웹','윅스','임웹'],
    '웹 제작': ['홈페이지', '쇼핑몰', '랜딩페이지', '튜닝', '웹', '랜딩', '제작','웹페이지','웹 제작'],
    '웹 유지보수': ['홈페이지','수정', '유지보수', '퍼블리싱', '검색최적화', 'SEO', '애널리틱스', '유지', '개발', '웹'],
    '프로그램 자동화': ['자동화', '알고리즘', '자료구조', '반복', '트레이딩뷰','매크로','티스토리','자동'],
    '크롤링.스크래핑': ['크롤링', '스크래핑', '크롤', '데이터'],
    '코딩': ['코딩','파이썬','프로그래밍','깃허브','스크립트'],
    '프로그램 유지보수': ['유지보수', '프로그램 수정', '프로그램', '재작'],
    '앱': ['앱', '안드로이드','웹앱'],
    '서버.클라우드': ['서버', '클라우드', '아마존','호스팅','리눅스'],
    '액셀.스프레드시트': ['엑셀', '스프레드시트', '구글'],
    '봇.챗봇': ['봇', '챗봇'],
    'AI.GPT': ['AI', 'GPT', '오픈소스'],
    '머신러닝 딥러닝': ['머신러닝', '딥러닝','머신'],
    '컴퓨터 비전.자연어 처리': ['컴퓨터 비전', '자연어'],
    '데이터 라벨링': ['라벨링'],
    '데이터 전처리.분석.시각화': ['전처리', '분석', '시각화'],
    '데이터베이스': ['데이터베이스', '쿼리'],
    '데이터 구매': ['데이터 구매', '구축', '수집'],
    '정보.보안': ['보안', '정보 보안'],
    'QA.테스트': ['QA', '테스트'],
    '게임·AR·VR': ['게임', 'AR', 'VR', '유니티'],
    '메타버스': ['메타버스'],
    '블록체인·NFT': ['블록체인', 'NFT','가상화폐','가상','가상 화폐','코인','컨트랙트'],
    '직무직군': ['UI', 'UX', '기획', '프론트엔드', '백엔드', '풀스택', '데브옵스', '인프라', 'ML', 'DL'],
    '서비스·MVP 개발': ['서비스 개발', 'MVP'],
    '컴퓨터 기술지원': ['기술지원', '기술 지원','기술'],
    '하드웨어·임베디드': ['하드웨어', '임베디드', '컴퓨터', '설치', '아두이노','라즈베리파이'],
    '교육·컨설팅': ['교육', '컨설팅', '튜토리얼', '강의', '학습'],
    '재무·회계': ['재무', '회계', '투자', '자산'],
    '마케팅·광고': ['광고', '마케팅', 'SEO', '콘텐츠', '브랜딩'],
    '번역·언어 서비스': ['번역', '통역', '언어'],
    '기타': ['기타', '장치']
}

# %%
for idx, row in df_unique.iterrows():
    service_name = row['서비스명']
    nouns = okt.nouns(service_name)  
    category_count = Counter()  

    for noun in nouns:
        for category, keywords in categories.items():
            if noun in keywords:
                category_count[category] += 1

    if category_count:
        most_common_category = category_count.most_common(1)[0][0]  
        df_unique.at[idx, '소분류'] = most_common_category
    else:
        df_unique.at[idx, '소분류'] = '기타'

# %%
df_unique[['서비스명', '소분류']].head(10)
# Out:
#                                    서비스명        소분류
# 0         카페24,고도몰,메이크샵등 쇼핑몰 수정,코딩,유지보수     웹 유지보수
# 2       엑셀 VBA, 매크로, ERP 프로그램 개발해 드립니다.  액셀.스프레드시트
# 3         엑셀을 이용 서식과 집계, 분석 및 VBA 프로그래밍  액셀.스프레드시트
# 11        카페24 쇼핑몰 수정 유지보수 제작 기능개선 오류개선       웹 제작
# 18           카페24 쇼핑몰 수정 및 개선작업 해 드립니다.       웹 제작
# 20            리눅스 서버 기술지원 서버이전 SSL 장애처리    서버.클라우드
# 21          워드프레스 홈페이지 수정, 오류 해결, 기능 추가     웹 유지보수
# 23       쎈스있는 카페24 수정유지보수 리뉴얼 코딩 해드립니다.     웹 유지보수
# 25  고도몰5 전문 튜닝 친절한 상담과 깔끔한 작업 진행해 드립니다.       웹 제작
# 28           알고리즘 자료구조 등 프로그램 제작해 드립니다.   프로그램 자동화

# %%
(df_unique['소분류'] == '기타').mean() * 100
# Out:
# 7.750269106566201

# %%
df_unique['소분류'].unique()
# Out:
# array(['웹 유지보수', '액셀.스프레드시트', '웹 제작', '서버.클라우드', '프로그램 자동화', '웹빌더',
#        '크롤링.스크래핑', '하드웨어·임베디드', '프로그램 유지보수', '앱', '컴퓨터 기술지원',
#        '데이터 전처리.분석.시각화', '게임·AR·VR', '코딩', '머신러닝 딥러닝', '블록체인·NFT',
#        '데이터베이스', '기타', 'AI.GPT', '번역·언어 서비스', '직무직군', '마케팅·광고', '데이터 구매',
#        '봇.챗봇', 'QA.테스트', '컴퓨터 비전.자연어 처리', '재무·회계', '정보.보안', '교육·컨설팅'],
#       dtype=object)

# %% [markdown]
# **전체비율**

# %%
df_unique['소분류'].value_counts(normalize=True) * 100
# Out:
# 소분류
# 웹 제작              23.968425
# 웹 유지보수            22.138500
# 기타                 7.750269
# 앱                  7.176175
# 웹빌더                5.633297
# 크롤링.스크래핑           5.023323
# 프로그램 유지보수          4.198062
# 프로그램 자동화           3.695730
# 액셀.스프레드시트          2.655185
# 하드웨어·임베디드          2.475780
# 게임·AR·VR           2.332257
# 코딩                 2.224614
# 서버.클라우드            1.973448
# 데이터 전처리.분석.시각화     1.363473
# 데이터 구매             1.291712
# 직무직군               1.219950
# 블록체인·NFT           1.076426
# 봇.챗봇               0.861141
# 마케팅·광고             0.574094
# 머신러닝 딥러닝           0.466451
# 컴퓨터 기술지원           0.322928
# 데이터베이스             0.287047
# QA.테스트             0.287047
# 교육·컨설팅             0.287047
# 정보.보안              0.251166
# 재무·회계              0.215285
# 번역·언어 서비스          0.179404
# AI.GPT             0.035881
# 컴퓨터 비전.자연어 처리      0.035881
# Name: proportion, dtype: float64

# %%
df_unique.to_csv('소분류버전.csv', index=False)
